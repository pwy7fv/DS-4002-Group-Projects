# %% [markdown]
# <a href="https://colab.research.google.com/github/pwy7fv/DS-4002-Group-Projects/blob/main/FF3_%2B_FF4_Vader_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#getting files from github repo
# !git clone https://github.com/pwy7fv/DS-4002-Group-Projects

# %%
df3.head()
# Out:
#    Index  Rating                                              Title  \
# 0      0    10.0  Definitely much better than Roper and Leno pai...
# 1      1     9.0             Good movie elevated by awesome action.
# 2      2     5.0                                              eh...
# 3      3    10.0               The fats and the furious Tokyo drift
# 4      4     5.0                    Eye Candy just like the other 2
#
#                                              Content         Author Name  \
# 0  For one thing, the caption that identifies the...           Carycomic
# 1  This movie has to be the most entertaining thi...      the_con_man298
# 2  if you like minimum plot concern, tricked-out ...  sketchbook_romance
# 3  I saw fast and the furious Tokyo drift today i...        igraynelewis
# 4  Fun, Fast and Flashy. Like the other 2 it most...           Physicker
#
#          Date  Year Sentiment Overall  Negative Score  Neutral SCore  \
# 0  2006-06-16  2006          Positive           0.022          0.899
# 1  2006-06-16  2006          Positive           0.022          0.669
# 2  2006-06-16  2006          Positive           0.011          0.909
# 3  2006-06-16  2006          Positive           0.046          0.750
# 4  2006-06-16  2006          Positive           0.110          0.743
#
#    Positive Score  Overall Percentage Score
# 0           0.080                    0.9714
# 1           0.309                    0.9956
# 2           0.080                    0.6808
# 3           0.204                    0.9964
# 4           0.147                    0.6444

# %%
# Plot the distribution

df3['Year'] = pd.to_datetime(df3['Year'], format='%Y')

plt.figure(figsize=(10, 5))
sns.histplot(df3['Year'].dt.year, bins=20, kde=True, color='skyblue')

# Labels and title
plt.xlabel("Year")
plt.ylabel("Number of Reviews")
plt.title("Distribution of Movie Reviews by Year")

# Show the plot
plt.show()

# %%
# Count occurrences of each sentiment per year
sentiment_counts = df3.groupby(["Year", "Sentiment Overall"]).size().reset_index(name="Count")

# Pivot the data to get Sentiment as columns
sentiment_pivot = sentiment_counts.pivot(index="Year", columns="Sentiment Overall", values="Count").fillna(0)

# Plot
plt.figure(figsize=(12, 6))
sentiment_pivot.plot(kind="bar", stacked=True, colormap="viridis", figsize=(12,6))

# Labels and Title
plt.xlabel("Year")
plt.ylabel("Number of Reviews")
plt.title("Sentiment Distribution of Reviews by Year")
plt.legend(title="Sentiment")
plt.xticks(rotation=45)

# Show Plot
plt.show()

# %%
# Filter data for 2006 and 2016-2025
df_2006 = df3[df3["Year"] == 2006]
df_2016_2025 = df3[(df3["Year"] >= 2016) & (df3["Year"] <= 2025)]

# Count sentiment occurrences
sentiment_2006 = df_2006["Sentiment Overall"].value_counts(normalize=True) * 100  # Count and Convert to percentage
sentiment_2016_2025 = df_2016_2025["Sentiment Overall"].value_counts(normalize=True) * 100  # Count and Convert to percentage

# Pie chart labels and colors
labels = ["Positive", "Neutral", "Negative"]
colors = ["#2ecc71", "#e74c3c","#f1c40f"]  # Green, Yellow, Red

# Create subplots for side-by-side pie charts
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart for 2006
axes[0].pie(sentiment_2006, labels=sentiment_2006.index, autopct='%1.1f%%', colors=colors, startangle=140)
axes[0].set_title("Sentiment Distribution (2006)")

# Pie chart for 2016-2025
axes[1].pie(sentiment_2016_2025, labels=sentiment_2016_2025.index, autopct='%1.1f%%', colors=colors, startangle=140)
axes[1].set_title("Sentiment Distribution (2016-2025)")

# Show the pie charts
plt.tight_layout()
plt.show()

# %%
#creating dataframe of FF4 data to analyze
df4 = pd.read_csv('/content/DS-4002-Group-Projects/DATA/Cleaned Data/FF4_clean_data.csv', low_memory=False)
df4.head()
# Out:
#    Index  Rating                                              Title  \
# 0      0     7.0                          Still fast, still furious
# 1      1     4.0                           First Five Minutes. Over
# 2      2     4.0                          In automatic transmission
# 3      3    10.0  Great action, Nice cars and plenty of sexy bab...
# 4      4     7.0                   The best of the series by a mile
#
#                                              Content         Author Name  \
# 0  Fast and Furious, or 4 Fast 4 Furious if you'r...           C-Younkin
# 1  Definitely, good for car-fans. Since I'm not o...  Mihnea_aka_Pitbull
# 2  Exhausted and pretty much running on synthetic...          Jay_Exiomo
# 3  I built this movie of 6 reels last night and s...         5klogiudice
# 4  I just got back from the midnight screening of...          phatrick88
#
#          Date  Year
# 0  2009-03-30  2009
# 1  2009-04-01  2009
# 2  2009-04-01  2009
# 3  2009-04-01  2009
# 4  2009-04-02  2009

# %%
# Plot the distribution

df4['Year'] = pd.to_datetime(df4['Year'], format='%Y')

plt.figure(figsize=(10, 5))
sns.histplot(df4['Year'].dt.year, bins=20, kde=True, color='skyblue')

# Labels and title
plt.xlabel("Year")
plt.ylabel("Number of Reviews")
plt.title("Distribution of Movie Reviews by Year")

# Show the plot
plt.show()

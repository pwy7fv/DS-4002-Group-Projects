# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# !pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# Requirement already satisfied: vaderSentiment in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.3.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->vaderSentiment) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->vaderSentiment) (2024.2.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
#Got this code from cited reference [13] in listed references in README
def sentiment_scores(index, row):
    # Extract Content, Author Name, Date, Rating
    sentence = row["Content"]
    name = row["Author Name"]
    title = row['Title']
    review_date = row["Date"]
    review_year = row["Year"]
    rating = row["Rating"]

    # Create a SentimentIntensityAnalyzer object
    sid_obj = SentimentIntensityAnalyzer()

    # Get sentiment scores
    sentiment_dict = sid_obj.polarity_scores(sentence)

    # Determine overall sentiment
    if sentiment_dict['compound'] >= 0.05:
        sentiment_label = "Positive"
    elif sentiment_dict['compound'] <= -0.05:
        sentiment_label = "Negative"
    else:
        sentiment_label = "Neutral"

    # Return sentiment results as a Series (so it's added as columns in the original DataFrame)
    return pd.Series({
        "Sentiment Overall": sentiment_label,
        "Negative Score": sentiment_dict['neg'],
        "Neutral Score": sentiment_dict['neu'],
        "Positive Score": sentiment_dict['pos'],
        "Overall Percentage Score": sentiment_dict['compound']
    })

# %%
FF5_clean2011_3 = pd.read_csv('/Users/borayadiul/DS-4002-Group-Projects/DATA/Cleaned Data/FF5_clean2011_3.csv')

# %%
# Vader analysis on FF5 2011 movies
FF5_clean2011_3[["Sentiment Overall", "Negative Score", "Neutral Score", "Positive Score", "Overall Percentage Score"]] = FF5_clean2011_3.apply(lambda row: sentiment_scores(row.name, row), axis=1)

# %%
FF5_2011_vader = FF5_clean2011_3
#FF5_2011_vader.to_csv('FF5_2011_vader.csv')
FF5_2011_vader
# Out:
#      Unnamed: 0  Rating                                              Title  \
# 0           159      10           Brilliant to me like previous releases!!
# 1           142       8  Not only did it suppress the surrounding hype,...
# 2            92       8  The stunts are pretty good, but the screenplay...
# 3            99       7        Ranks up right up there with the first one!
# 4           165      10            great movie but missed the post credits
# ..          ...     ...                                                ...
# 139          56       7                                Too Stupid, Too Fun
# 140          70       5                     How to mess up an action movie
# 141          51       9  have to admit..wasn't expecting this film to b...
# 142         190       4  Pretty average, shallow story, what else did I...
# 143          81       9                      Fast 5 is the BEST hands down
#
#                                                Content      Author Name  \
# 0    Fast and Furious Fast Five movie, with Vin Die...      sabbirworld
# 1    I couldn't help but to applaud and cheer after...          k-dhesi
# 2    How it possible that everything they needed wo...  rightwingisevil
# 3    Wow although being a huge 'mark' for Dwayne Jo...       thekyles99
# 4    This was an excellent movie prolly the best of...    lazyboy101991
# ..                                                 ...              ...
# 139  Some films can be so idiotic that an audience ...  TheDarkKnight21
# 140  I confess to not being a big fan of the 'Fast....          NDanger
# 141  Everyone use to talk about how they are excite...       amy-john99
# 142  Fast and Furios has been going for a while now...      evan_harvey
# 143  I LOVED this movie!!! The action scenes are ex...         cedicedi
#
#            Date  Year Sentiment Overall  Negative Score  Neutral Score  \
# 0    2011-04-28  2011          Positive           0.042          0.893
# 1    2011-04-28  2011          Positive           0.164          0.630
# 2    2011-04-28  2011          Positive           0.054          0.814
# 3    2011-04-29  2011          Positive           0.051          0.785
# 4    2011-04-29  2011          Positive           0.059          0.809
# ..          ...   ...               ...             ...            ...
# 139  2011-05-22  2011          Positive           0.127          0.707
# 140  2011-05-24  2011          Negative           0.083          0.857
# 141  2011-05-25  2011          Positive           0.068          0.664
# 142  2011-05-27  2011          Negative           0.162          0.729
# 143  2011-05-27  2011          Positive           0.055          0.697
#
#      Positive Score  Overall Percentage Score
# 0             0.065                    0.1154
# 1             0.206                    0.9814
# 2             0.131                    0.9712
# 3             0.164                    0.9893
# 4             0.132                    0.8931
# ..              ...                       ...
# 139           0.167                    0.9914
# 140           0.060                   -0.5358
# 141           0.268                    0.9911
# 142           0.109                   -0.9804
# 143           0.248                    0.9889
#
# [144 rows x 12 columns]

# %%
# Now Vader analysis for FF5 post 10 years

# %%
#Got this code from cited reference [13] in listed references in README
def sentiment_scores(index, row):
    # Extract Content, Author Name, Date, Rating
    sentence = row["Content"]
    name = row["Author Name"]
    title = row['Title']
    review_date = row["Date"]
    review_year = row["Year"]
    rating = row["Rating"]

    # Create a SentimentIntensityAnalyzer object
    sid_obj = SentimentIntensityAnalyzer()

    # Get sentiment scores
    sentiment_dict = sid_obj.polarity_scores(sentence)

    # Determine overall sentiment
    if sentiment_dict['compound'] >= 0.05:
        sentiment_label = "Positive"
    elif sentiment_dict['compound'] <= -0.05:
        sentiment_label = "Negative"
    else:
        sentiment_label = "Neutral"

    # Return sentiment results as a Series (so it's added as columns in the original DataFrame)
    return pd.Series({
        "Sentiment Overall": sentiment_label,
        "Negative Score": sentiment_dict['neg'],
        "Neutral Score": sentiment_dict['neu'],
        "Positive Score": sentiment_dict['pos'],
        "Overall Percentage Score": sentiment_dict['compound']
    })

# %%
FF5_clean_dec2 = pd.read_csv('/Users/borayadiul/DS-4002-Group-Projects/Scripts/FF5_clean_dec2.csv')

# %%
# Vader analysis on FF5 2011 movies
FF5_clean_dec2[["Sentiment Overall", "Negative Score", "Neutral Score", "Positive Score", "Overall Percentage Score"]] = FF5_clean_dec2.apply(lambda row: sentiment_scores(row.name, row), axis=1)
FF5_dec_vader = FF5_clean_dec2
FF5_dec_vader
# Out:
#      Unnamed: 0  Rating                                              Title  \
# 0             9    10.0                                        my no1 film
# 1           121     8.0  If they failed on the 2nd, 3rd and 4th attempt...
# 2            44    10.0                                   Best action film
# 3            35     8.0  Fast Five (2011, Justin Lin) The Fast franchis...
# 4            97     2.0              OK the same story but a bit stretched
# ..          ...     ...                                                ...
# 131         488     9.0  Fast Five: Revving Up the Franchise to a New L...
# 132         110     7.0  A Thrilling Evolution of the Franchise with So...
# 133         192     6.0       This one depends on what you are looking for
# 134         470    10.0  The Return of Muscle, Schemes, and Screaming T...
# 135         488     9.0  Fast Five: Revving Up the Franchise to a New L...
#
#                                                Content   Author Name  \
# 0    This film made me. This has always been my fav...       miacoop
# 1    Of everything that involves this franchise (ca...  prietoheitor
# 2    Last week I saw Fast and Furious 5 / Fast five...    imdb-58910
# 3    Fast Five (2011, Justin Lin) 'Fast Five' is na...     hoernkeem
# 4    Not liking the franchise so far, becoming very...  TheNonSmoker
# ..                                                 ...           ...
# 131  Fast Five is a shot of pure adrenaline straigh...    douglasc11
# 132  Fast Five marks a pivotal moment in the Fast &...      fahimrcs
# 133  I was wondering when I would when the point wh...    jaredlemin
# 134  Dom and his crew of illegal mechanics are back...         OniFR
# 135  Fast Five is a shot of pure adrenaline straigh...    douglasc11
#
#            Date  Year Sentiment Overall  Negative Score  Neutral Score  \
# 0    2021-01-11  2021          Positive           0.000          0.819
# 1    2021-01-16  2021          Negative           0.107          0.841
# 2    2021-02-07  2021          Positive           0.093          0.726
# 3    2021-02-17  2021          Positive           0.055          0.820
# 4    2021-03-19  2021          Negative           0.394          0.606
# ..          ...   ...               ...             ...            ...
# 131  2025-01-05  2025          Positive           0.067          0.753
# 132  2025-01-17  2025          Positive           0.026          0.762
# 133  2025-01-30  2025          Positive           0.075          0.840
# 134  2025-02-07  2025          Positive           0.109          0.759
# 135  2025-01-05  2025          Positive           0.067          0.753
#
#      Positive Score  Overall Percentage Score
# 0             0.181                    0.9038
# 1             0.052                   -0.4185
# 2             0.181                    0.9711
# 3             0.125                    0.9941
# 4             0.000                   -0.5501
# ..              ...                       ...
# 131           0.180                    0.9968
# 132           0.213                    0.9952
# 133           0.085                    0.3699
# 134           0.132                    0.7626
# 135           0.180                    0.9968
#
# [136 rows x 12 columns]

# %%
FF5_dec_vader.to_csv('FF5_dec_vader.csv')
FF5_dec_vader
# Out:
#      Unnamed: 0  Rating                                              Title  \
# 0             9    10.0                                        my no1 film
# 1           121     8.0  If they failed on the 2nd, 3rd and 4th attempt...
# 2            44    10.0                                   Best action film
# 3            35     8.0  Fast Five (2011, Justin Lin) The Fast franchis...
# 4            97     2.0              OK the same story but a bit stretched
# ..          ...     ...                                                ...
# 131         488     9.0  Fast Five: Revving Up the Franchise to a New L...
# 132         110     7.0  A Thrilling Evolution of the Franchise with So...
# 133         192     6.0       This one depends on what you are looking for
# 134         470    10.0  The Return of Muscle, Schemes, and Screaming T...
# 135         488     9.0  Fast Five: Revving Up the Franchise to a New L...
#
#                                                Content   Author Name  \
# 0    This film made me. This has always been my fav...       miacoop
# 1    Of everything that involves this franchise (ca...  prietoheitor
# 2    Last week I saw Fast and Furious 5 / Fast five...    imdb-58910
# 3    Fast Five (2011, Justin Lin) 'Fast Five' is na...     hoernkeem
# 4    Not liking the franchise so far, becoming very...  TheNonSmoker
# ..                                                 ...           ...
# 131  Fast Five is a shot of pure adrenaline straigh...    douglasc11
# 132  Fast Five marks a pivotal moment in the Fast &...      fahimrcs
# 133  I was wondering when I would when the point wh...    jaredlemin
# 134  Dom and his crew of illegal mechanics are back...         OniFR
# 135  Fast Five is a shot of pure adrenaline straigh...    douglasc11
#
#            Date  Year Sentiment Overall  Negative Score  Neutral Score  \
# 0    2021-01-11  2021          Positive           0.000          0.819
# 1    2021-01-16  2021          Negative           0.107          0.841
# 2    2021-02-07  2021          Positive           0.093          0.726
# 3    2021-02-17  2021          Positive           0.055          0.820
# 4    2021-03-19  2021          Negative           0.394          0.606
# ..          ...   ...               ...             ...            ...
# 131  2025-01-05  2025          Positive           0.067          0.753
# 132  2025-01-17  2025          Positive           0.026          0.762
# 133  2025-01-30  2025          Positive           0.075          0.840
# 134  2025-02-07  2025          Positive           0.109          0.759
# 135  2025-01-05  2025          Positive           0.067          0.753
#
#      Positive Score  Overall Percentage Score
# 0             0.181                    0.9038
# 1             0.052                   -0.4185
# 2             0.181                    0.9711
# 3             0.125                    0.9941
# 4             0.000                   -0.5501
# ..              ...                       ...
# 131           0.180                    0.9968
# 132           0.213                    0.9952
# 133           0.085                    0.3699
# 134           0.132                    0.7626
# 135           0.180                    0.9968
#
# [136 rows x 12 columns]

# %%
# These are now the 2 sample t-test analysis

import numpy as np
import scipy.stats as stats

# Extract the overall sentiment scores from both datasets
sentiment_FF52011 = np.array(FF5_2011_vader["Overall Percentage Score"]) 
sentiment_FF5dec = np.array(FF5_dec_vader["Overall Percentage Score"]) 

# Print variance of both groups (checking assumption of equal variance)
var_FF52011 = np.var(sentiment_FF52011, ddof=1)  # Sample variance (ddof=1 for unbiased estimate)
var_FF5dec = np.var(sentiment_FF5dec, ddof=1)

print(f"Variance of 2011 Sentiment Scores: {var_FF52011:.4f}")
print(f"Variance of 2021-2025 Sentiment Scores: {var_FF5dec:.4f}")

# Perform the two-sample t-test (Welch’s t-test since variances might be unequal)
t_stat, p_value = stats.ttest_ind(sentiment_FF52011, sentiment_FF5dec, equal_var=False)

# Display results
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in sentiment between 2011 and 2021-2025.")
else:
    print("Fail to reject the null hypothesis: No significant difference in sentiment.")
# Out:
# Variance of 2011 Sentiment Scores: 0.4333
# Variance of 2021-2024 Sentiment Scores: 0.2514
# T-statistic: -1.4609
# P-value: 0.1452
# Fail to reject the null hypothesis: No significant difference in sentiment.

# %%
# Group by the 'Year' column and calculate the mean of 'Overall Percentage Score'
avg_sentiment_FF52011 = FF5_2011_vader['Overall Percentage Score'].mean()
avg_sentiment_FF5dec = FF5_dec_vader['Overall Percentage Score'].mean()

print(f"Average sentiment score for 2011: {avg_sentiment_FF52011}")
print(f"Average sentiment score for 2021 - 2025: {avg_sentiment_FF5dec}")
# Out:
# Average sentiment score for 2011: 0.6232326388888888
# Average sentiment score for 2021 - 2024: 0.7250536764705883

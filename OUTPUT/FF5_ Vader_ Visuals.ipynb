# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

FF5_2011_vader = pd.read_csv('/Users/borayadiul/DS-4002-Group-Projects-1/DATA/Cleaned Data/Vader Included Datasets/FF5_2011_vader.csv')
FF5_dec_vader = pd.read_csv('/Users/borayadiul/DS-4002-Group-Projects-1/DATA/Cleaned Data/Vader Included Datasets/FF5_dec_vader.csv')

# %%
# Plotting histograms for both periods
plt.figure(figsize=(12, 6))

# Histogram for 2011
plt.subplot(1, 2, 1)
plt.hist(FF5_2011_vader['Overall Percentage Score'], bins=20, color='forestgreen', edgecolor='black', alpha=0.7)
plt.title('Sentiment Distribution (2011)')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')

# Histogram for 2021-2025
plt.subplot(1, 2, 2)
plt.hist(FF5_dec_vader['Overall Percentage Score'], bins=20, color='steelblue', edgecolor='black', alpha=0.7)
plt.title('Sentiment Distribution (2021-2025)')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Plotting box plots for both periods
plt.figure(figsize=(8, 6))

# Box plot for 2011
plt.boxplot(FF5_2011_vader['Overall Percentage Score'], positions=[1], widths=0.5, patch_artist=True,
            boxprops=dict(facecolor='forestgreen', color='black'), medianprops=dict(color='black'))

# Box plot for 2021-2025
plt.boxplot(FF5_dec_vader['Overall Percentage Score'], positions=[2], widths=0.5, patch_artist=True,
            boxprops=dict(facecolor='steelblue', color='black'), medianprops=dict(color='black'))

plt.xticks([1, 2], ['2011', '2021-2025'])
plt.title('Sentiment Distribution by Year Range')
plt.ylabel('Sentiment Score')

plt.show()

# %%
FF5_2011_vader
# Out:
#      Unnamed: 0.1  Unnamed: 0  Rating  \
# 0               0         159      10
# 1               1         142       8
# 2               2          92       8
# 3               3          99       7
# 4               4         165      10
# ..            ...         ...     ...
# 139           139          56       7
# 140           140          70       5
# 141           141          51       9
# 142           142         190       4
# 143           143          81       9
#
#                                                  Title  \
# 0             Brilliant to me like previous releases!!
# 1    Not only did it suppress the surrounding hype,...
# 2    The stunts are pretty good, but the screenplay...
# 3          Ranks up right up there with the first one!
# 4              great movie but missed the post credits
# ..                                                 ...
# 139                                Too Stupid, Too Fun
# ...

# %%
# Count the number of positive, negative, and neutral reviews for both periods
sentiment_counts_11 = FF5_2011_vader['Overall Sentiment'].value_counts()
sentiment_counts_dec21 = FF5_dec_vader['Overall Sentiment'].value_counts()

# Convert the counts to dataframes for easy plotting
sentiment_counts_11_df = sentiment_counts_11.reset_index()
sentiment_counts_11_df.columns = ['Sentiment', 'Count']
sentiment_counts_11_df['Period'] = '2011'

sentiment_counts_dec21_df = sentiment_counts_dec.reset_index()
sentiment_counts_dec21_df.columns = ['Sentiment', 'Count']
sentiment_counts_dec21_df['Period'] = '2021-2025'

# Plot for 2011 reviews
plt.figure(figsize=(8, 5))
sns.barplot(x='Sentiment', y='Count', data=sentiment_counts_11_df, palette='Set2')
plt.title('Sentiment Distribution in 2011 Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Count of Reviews')
plt.show()

# Plot for 2021-2025 reviews
plt.figure(figsize=(8, 5))
sns.barplot(x='Sentiment', y='Count', data=sentiment_counts_dec21_df, palette='Set2')
plt.title('Sentiment Distribution in 2021-2025 Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Count of Reviews')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Overall Sentiment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
# ...

# %%
# Count sentiment occurrences and convert to percentages
sentiment_06 = df3_vader06["Overall Sentiment"].value_counts(normalize=True) * 100  # Convert to percentage
sentiment_dec = df3_vader_dec["Overall Sentiment"].value_counts(normalize=True) * 100  # Convert to percentage

# Pie chart labels and colors
labels = ["Positive", "Neutral", "Negative"]
colors = ["#2ecc71", "#e74c3c", "#f1c40f"]  # Green, Red, Yellow

# Create subplots for side-by-side pie charts
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart for 2006
axes[0].pie(sentiment_06, labels=sentiment_06.index, autopct='%1.1f%%', colors=colors, startangle=140)
axes[0].set_title("Sentiment Distribution (2006)")

# Pie chart for 2016-2025
axes[1].pie(sentiment_dec, labels=sentiment_dec.index, autopct='%1.1f%%', colors=colors, startangle=140)
axes[1].set_title("Sentiment Distribution (2016-2025)")

# Show the pie charts
plt.tight_layout()
plt.show()

# %%
# Concatenate both datasets into a single DataFrame
df3_combined = pd.concat([df3_vader06, df3_vader_dec], ignore_index=True)

# 2. Group by Year, Sentiment Overall, and Period
sentiment_counts_combined = df3_combined.groupby(["Year", "Overall Sentiment"]).size().reset_index(name="Count")

# 3. Pivot the data to get Sentiment as columns
sentiment_pivot_combined = sentiment_counts_combined.pivot_table(index=["Year"],
                                                                columns="Overall Sentiment",
                                                                values="Count",
                                                                aggfunc="sum",
                                                                fill_value=0).reset_index()

# 4. Plotting
plt.figure(figsize=(12, 6))

# Create a bar plot with 'Year' on the x-axis, and sentiment counts on the y-axis
sentiment_pivot_combined.plot(kind="bar", x="Year", stacked=True, colormap="viridis", figsize=(12, 6), ax=plt.gca())

# Labels and Title
plt.xlabel("Year")
plt.ylabel("Number of Reviews")
plt.title("Sentiment Distribution of Reviews by Year (2006 vs 2016-2025)")
plt.legend(title="Sentiment", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()
